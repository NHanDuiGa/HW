# %% [markdown]
# # HW01: Các câu lệnh Linux, Python
#
# (Cập nhật lần cuối 08/11/2025)
#
# Họ tên: Thạch Ngọc Hân
#
# MSSV: 23127361

# %% [markdown]
# ---

# %% [markdown]
# ## Cách làm bài và nộp bài

# %% [markdown]
# &#9889; Bạn lưu ý là mình sẽ dùng chương trình hỗ trợ chấm bài nên bạn cần phải tuân thủ chính xác qui định mà mình đặt ra, nếu không rõ thì hỏi, chứ không nên tự tiện làm theo ý của cá nhân.
#
# **Cách làm bài**
#
# Bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV vào phần đầu file ở bên trên. Trong file, bạn làm bài ở những chỗ có ghi là:
# ```python
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
# hoặc đối với những phần code không bắt buộc thì là:
# ```python
# # YOUR CODE HERE (OPTION)
# ```
# hoặc đối với markdown cell thì là:
# ```markdown
# YOUR ANSWER HERE
# ```
# Tất nhiên, khi làm thì bạn xóa dòng `raise NotImplementedError()` đi.
# Đối những phần yêu cầu code thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa; nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test. Trong một số trường hợp, các bộ test có thể sẽ không đầy đủ; nghĩa là, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng hoàn toàn.
#
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Nhưng khi nộp bài thì bạn xóa các cell mà bạn tự tạo, xóa hoặc comment các câu lệnh in ra màn hình. Bạn lưu ý <font color=red>không được tự tiện xóa các cell hay sửa code của Thầy</font> (trừ những chỗ được phép sửa như đã nói ở trên).
#
# Bạn cố gắng giữ cho code rõ ràng, ngăn nắp: đặt tên biến gợi ý, comment ở những chỗ cần comment, giữ cho một dòng code không quá dài (vì nếu không thì người đọc sẽ phải mất công scroll, bạn có thể dùng qui tắc: một dòng code chỉ nên có tối đa là 79 ký tự).
#
# Trong khi làm bài, thường xuyên `Ctrl + S` để lưu lại bài làm của bạn, tránh mất mát thông tin.
#
#
# *Nên nhớ mục tiêu chính ở đây là <font color=green>học, học một cách chân thật</font>. Bạn có thể thảo luận ý tưởng với bạn khác, nhưng <font color=green>code và bài làm phải là của bạn, dựa trên sự hiểu thật sự của bạn</font>. <font color=red>Nếu vi phạm thì sẽ bị 0 điểm cho toàn bộ môn học.</font>*
#
# **Cách nộp bài**
#
# Khi chấm bài, đầu tiên mình sẽ chọn `Kernel` - `Restart & Run All` để restart và chạy tất cả các cell trong notebook của bạn; do đó, trước khi nộp bài, bạn nên chạy thử `Kernel` - `Restart & Run All` để đảm bảo mọi chuyện diễn ra đúng như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo cấu trúc sau:
# - Thư mục `MSSV` (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`)
#     - File `HW01.ipynb` (không cần nộp các file khác)
#
# Cuối cùng, bạn nén thư mục `MSSV` này lại và nộp ở link trên moodle. <font color=red>Bạn lưu ý tuân thủ chính xác qui định nộp bài.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Môi trường code

# %% [markdown]
# Ta thống nhất trong môn này:
# - Code trên môi trường Linux (bạn đã setup ở HW0)
# - Dùng Jupyter Notebook hoặc Jupyter Lab để code file .ipynb. Lưu ý: bạn <font color=red>không dùng Google Colab</font>, vì Google Colab có thể xóa một số thông tin meta mà chương trình hỗ trợ chấm bài của mình đã tạo trong file bài tập
# - Dùng phiên bản các package như trong file "min_ds-env.yml" (bạn xem trong HW0 cách dùng Conda để tạo môi trường code từ file .yml và cách kích hoạt môi trường này sau khi đã tạo)

# %%
import sys
sys.executable
# Out:
# '/home/kimkh/HW01/.venv/bin/python'

# %% [markdown]
# Nếu không có vấn đề gì thì file chạy python sẽ là file của môi trường code "min_ds-env".
#
# Trong bài này, ngoài Git & Jupyter Notebook/Lab thì bạn chỉ dùng Python, không dùng các thư viện khác như Numpy, Pandas, ... Trong Python, khi đọc/ghi file csv thì bạn cũng không được dùng các thư viện hỗ trợ như thư viện `csv`.

# %% [markdown]
# ---

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import datetime
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ---

# %% [markdown]
# ## Thu thập dữ liệu (3.5đ)

# %% [markdown]
# Trong bài tập này, bạn sẽ lấy dữ liệu log của [thùng chứa nbdime](https://github.com/namlnhut/nbdime). Nbdime là công cụ giúp Git có thể diff và merge file Notebook một cách phù hợp (thay vì chỉ coi như là một file text thông thường). Link mình cung cấp không phải là link đến thùng chứa gốc của nbdime mà là thùng chứa mình "fork" (đại khái là tạo ra một bản copy) từ thùng chứa gốc. Lý do: mình muốn cố định lại dữ liệu log để có thể cung cấp các bộ test để bạn phần nào biết là đã code đúng hay chưa (còn nếu dùng thùng chứa gốc thì dữ liệu log có thể sẽ thay đổi trong vài ngày tới, các bộ test lúc đó có thể sẽ không còn đúng nữa).
#
# Để có thể lấy dữ liệu log thì việc đầu tiên bạn cần làm ở cell bên dưới là:
#
# - Dùng câu lệnh Git để clone thùng chứa về; bạn clone vào một thư mục cùng cấp với file notebook này. <font color=gray>Gợi ý: trong Jupyter Notebook, ở code cell, bạn có thể thực hiện một câu lệnh Linux (bao gồm câu lệnh Git) bằng cách thêm dấu ! ở đầu.</font>
# - Sau đó, để xem thử thư mục vừa clone có nặng không, bạn tính dung lượng tổng cộng của thư mục này và lưu vào biến `repo_size` (`repo_size` là một con số, đơn vị là MB); ta thống nhất: (i) dùng cờ `--apparent-size` khi dùng câu lệnh `du`, (ii) code chỉ cần chạy đúng với thùng chứa cụ thể này. <font color=gray>Gợi ý: trong Jupyter Notebook, bạn có thể gán kết quả của câu lệnh Linux vào biến Python.</font> \
# @ Các bạn dùng Mac: trong Mac thì mình nghe nói là câu lệnh `du` không có cờ `--apparent-size` (do câu lệnh `du` của Mac là bản BSD, còn của Linux là bản GNU); bạn có thể xem thử cách cài câu lệnh `du` bản GNU ở [video này](https://youtu.be/VGgTmxXp7xQ?t=894) (trong video là nói về câu lệnh `grep` nhưng mình nghĩ cũng sẽ tương tự với câu lệnh `du`).

# %%
# !git clone https://github.com/namlnhut/nbdime nbdime_repo
# Out:
# fatal: destination path 'nbdime_repo' already exists and is not an empty directory.

# %%
# YOUR CODE HERE
tmp = !du -sh --apparent-size nbdime_repo | awk '{print $1}'
repo_size = tmp[0]
print(f"Repository size: {repo_size}")
# Out:
# Repository size: 21M

# %% [markdown]
# Sau khi đã clone thùng chứa về, việc kế tiếp của bạn là dùng các câu lệnh Linux (trong đó có các câu lệnh Git) và Python để lấy dữ liệu log rồi lưu xuống file "log.tsv" (định dạng tsv tương tự như csv nhưng các giá trị được cách nhau bởi tab). Để dễ hình dung, bạn có thể dùng Jupyter Lab để mở xem file kết quả đúng "correct_log.tsv" mà mình cung cấp. Như bạn có thể thấy, mỗi dòng ứng với một commit (không tính dòng đầu - dòng chứa các tên cột) và gồm các thông tin:
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit, ngày được format theo chuẩn RFC2822 (xem phần gợi ý ở bên dưới để biết cách lấy ngày theo format này)
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy
#
# Tại sao mình dùng định dạng tsv thay vì csv? Vì dấu phẩy nhiều khả năng là sẽ có trong phần "subject" của message. Tab ít khả năng sẽ có hơn, nhưng nếu có thì bạn hãy thay bằng bốn khoảng trắng.
#
# <font color=gray>Gợi ý cho phần này:</font>
# - <font color=gray>Bạn có thể xem thêm về câu lệnh `git log` [ở đây](https://git-scm.com/book/en/v2/Git-Basics-Viewing-the-Commit-History)</font>
# - <font color=gray>Khi ở Notebook, bạn thử `cd` đến thư mục clone rồi `pwd` xem? Kết quả như vậy là vì khi thực hiện một dòng lệnh Linux ở Notebook thì Notebook sẽ tạo ra một terminal tạm thời để thực thi dòng lệnh đó trong phút chốc. Như vậy, câu lệnh `cd` vẫn là có `cd` đến thư mục clone nhưng là ở terminal tạm thời; khi câu lệnh `cd` chạy xong thì terminal tạm thời này sẽ được đóng và ta vẫn ở thư mục mà hiện chứa file Notebook. Để có thể `cd` rồi `pwd` thì một cách là ghi 2 câu lệnh này trên một dòng và cách nhau bởi `&&`; lúc này thì cả 2 câu lệnh sẽ được thực thi trên cùng một terminal</font>

# %%
# YOUR CODE HERE
git_log_output = !cd nbdime_repo && git log --pretty=format:"---COMMIT_START---%n%h%n%p%n%an%n%ae%n%aD%n%s" --name-only
log_data_str = "\n".join(git_log_output)
commit_blocks = log_data_str.split("---COMMIT_START---")[1:]

output_filename = "log.tsv"
header = "Id\tParentIds\tAuthorName\tAuthorEmail\tAuthorDate\tSubject\tChangedFiles\n"

with open(output_filename, "w", encoding="utf-8") as f:
    f.write(header)
    
    for block in commit_blocks:
        block = block.strip() 
        if not block:
            continue 
        
        lines = block.split('\n')
        if len(lines) < 6:
            continue 
        
        commit_id = lines[0].strip()
        parent_ids = lines[1].strip()
        author_name = lines[2].strip()
        author_email = lines[3].strip()
        author_date = lines[4].strip()
        subject = lines[5].strip()
        
        subject = subject.replace('\t', '    ')
        file_list = [line.strip() for line in lines[6:] if line.strip()]
        files_str = ",".join(file_list)
        
        f.write(f"{commit_id}\t{parent_ids}\t{author_name}\t{author_email}\t{author_date}\t{subject}\t{files_str}\n")

# %%
# TEST
file = open('log.tsv', 'r')
log = file.read()
file.close()
file = open('correct_log.tsv', 'r')
correct_log = file.read()
file.close()
assert log == correct_log

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột? (0.5đ)

# %% [markdown]
# Đầu tiên, bạn sẽ đọc dữ liệu từ file "log.tsv" (nếu phần thu thập dữ liệu bạn làm chưa đúng thì bạn có thể đọc từ file "correct_log.tsv" mà mình đã cung cấp). Bạn lưu kết quả đọc được vào biến `cols`. Biến `cols` là một dictionary, trong đó mỗi phần tử ứng với một cột, key là chuỗi ứng với tên cột, value là list chứa các giá trị của cột (mỗi giá trị bạn cứ tạm để kiểu dữ liệu là chuỗi).
#
# Kế tiếp, từ biến `cols`, bạn sẽ tính số dòng và số cột, rồi lần lượt lưu vào hai biến là `num_rows` và `num_cols`.

# %%
# YOUR CODE HERE
filename = "log.tsv"
with open(filename, 'r', encoding='utf-8') as f:
    content = f.read()

lines = content.strip().split('\n')
header = lines[0].split('\t')
data_lines = lines[1:]

cols = {col_name: [] for col_name in header}

for line in data_lines:
    values = line.split('\t')
    for i, col_name in enumerate(header):
        if i < len(values):
            cols[col_name].append(values[i])
        else:
            cols[col_name].append("") 

num_rows = len(data_lines)
num_cols = len(header)

# %%
# TEST
assert num_rows == 2149
assert num_cols == 7
assert set(cols.keys()) == set(['Id', 'ParentIds', 'AuthorName', 
                                'AuthorEmail', 'AuthorDate', 'Subject', 
                                'ChangedFiles'])
id_col_len = len(cols['Id'])
for col_name in cols:
    assert len(cols[col_name]) == id_col_len

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng ứng với một commit. Có vẻ không có dòng nào "lạc loài" (nghĩa là không có vấn đề các dòng có ý nghĩa khác nhau).

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không? (0.25đ)

# %% [markdown]
# Có lẽ là không có. Để chắc ăn thì một cách là ta có thể check cột "Id"; nếu cột "Id" không có giá trị bị lặp thì có thể kết luận là không có dòng bị lặp. Bạn sẽ làm vụ này và lưu kết quả check vào biến `duplicated_id`; biến này bằng True nếu cột "Id" có giá trị lặp và bằng False nếu ngược lại.

# %%
# YOUR CODE HERE
id_list = cols['Id']
unique_ids = set(id_list)
duplicated_id = len(unique_ids) != len(id_list)

# %%
# TEST
assert duplicated_id == False

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì?

# %% [markdown]
# Vụ này mình đã nói lúc thu thập dữ liệu. Ở đây, mình ghi lại một lần nữa:
#
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không?

# %% [markdown]
# - Các cột "Id", "ParentIds", "AuthorName", "AuthorEmail", "Subject": kiểu dữ liệu dạng chuỗi là đúng rồi
# - Cột "ChangedFiles": hmm ... có lẽ tạm thời ta vẫn để dạng chuỗi, có gì cần thì ta sẽ xử lý sau
# - Cột "AuthorDate": cần chuyển từ kiểu dữ liệu dạng chuỗi sang datetime; để có thể tiếp tục khám phá tiếp thì ngay sau đây bạn sẽ tiền xử lý vụ này luôn

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Ở đây, bạn sẽ chuyển cột "AuthorDate" từ dạng chuỗi sang datetime. <font color=gray>Gợi ý: bạn xem [document](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes) để biết cách truyền format phù hợp cho hàm `strptime`.</font>

# %%
# YOUR CODE HERE
date_format = "%a, %d %b %Y %H:%M:%S %z"

converted_dates = []
for date_str in cols['AuthorDate']:
    dt = datetime.datetime.strptime(date_str.strip(), date_format)
    converted_dates.append(dt)

cols['AuthorDate'] = converted_dates

# %%
# TEST
assert type(cols['AuthorDate'][0]) == datetime.datetime
assert cols['AuthorDate'][0] == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu (tiếp tục)

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số (numeric) và dạng datetime, các giá trị được phân bố như thế nào? (0.5đ)

# %% [markdown]
# Ở đây thì không có cột dạng số, chỉ có một cột dạng datetime là cột "AuthorDate".
#
# Đầu tiên, bạn tính tỉ lệ % các giá trị thiếu của cột "AuthorDate". <font color=gray>Gợi ý: không cần code, có thể lập luận dựa vào kết quả khi chuyển cột "AuthorDate" từ dạng chuỗi sang datetime ở bên trên.</font>

# %% [markdown]
# YOUR ANSWER HERE
#
# Không có giá trị nào bị lỗi khi chuyển sang `datetime`
# → **Tỉ lệ giá trị thiếu: 0%**

# %% [markdown]
# Tiếp theo, bạn tính min và max của cột "AuthorDate", rồi lần lượt lưu vào hai biến `author_date_min` và `author_date_max`.

# %%
# YOUR CODE HERE
author_date_min = min(cols["AuthorDate"])
author_date_max = max(cols["AuthorDate"])

# %%
# TEST
assert author_date_min == datetime.datetime(2015, 11, 9, 13, 13, 28, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))
assert author_date_max == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# Hmm ... Min và max của cột "AuthorDate" không có gì bất thường.

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng phân loại (categorical), các giá trị được phân bố như thế nào? (1.75đ)

# %% [markdown]
# Các cột dạng phân loại là các cột mà không phải là cột "AuthorDate". Bạn sẽ lưu thông tin của các cột này vào biến `cate_col_profiles`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một cột dạng phân loại, key là tên cột, value là list gồm: tỉ lệ % giá trị thiếu, số lượng các giá trị khác nhau (không tính giá trị thiếu), set chứa các giá trị khác nhau (không bao gồm giá trị thiếu).

# %%
# YOUR CODE HERE
categorical_cols = [col for col in cols if col != "AuthorDate"]
cate_col_profiles = {}

for col in categorical_cols:
    values = cols[col]
    num_missing = sum(1 for v in values if v == "")
    missing_ratio = num_missing / len(values) * 100
    unique_values = set(v for v in values if v != "")
    num_unique = len(unique_values)
    cate_col_profiles[col] = [missing_ratio, num_unique, unique_values]

# %%
# TEST
assert set(cate_col_profiles.keys()) == {'AuthorEmail', 'AuthorName', 
                                         'ChangedFiles', 'Id', 
                                         'ParentIds', 'Subject'}
for col_name, col_profile in cate_col_profiles.items():
    assert len(col_profile) == 3
    assert len(col_profile[2]) == col_profile[1]
assert round(cate_col_profiles['ParentIds'][0], 3) == 0.047
assert round(cate_col_profiles['ChangedFiles'][0], 3) == 15.914
assert cate_col_profiles['ParentIds'][1] == 2029
assert cate_col_profiles['ChangedFiles'][1] == 934

# %%
# TEST (BY EYES)
print(f"{'ColName':12} {'Miss(%)':7} {'NumDifVals':10} {'SomeVals'}")
for col_name, col_profile in cate_col_profiles.items():
    print(f'{col_name:12} {col_profile[0]:<7.3f} {col_profile[1]:<10} {col_profile[2].__repr__()[:34]+"...":<}')
# Out:
# ColName      Miss(%) NumDifVals SomeVals
# Id           0.000   2149       {'2cd6efe', 'fd69229', '8ca8c6f', ...
# ParentIds    0.047   2029       {'fd69229', '8ca8c6f', 'fba5c31', ...
# AuthorName   0.000   55         {'Tony Hirst', 'Todd', 'Nicholas B...
# AuthorEmail  0.000   58         {'piotr.chromiec@rtbhouse.com', 't...
# Subject      0.000   2058       {'Merge pull request #372 from min...
# ChangedFiles 15.914  934        {'nbdime/tests/test_js_artifacts_i...

# %% [markdown]
# Bạn quan sát kết quả in ra ở trên (tạm thời chưa để ý đến cột "Miss(%)") và cho biết có gì bất thường không? Hay mọi thứ đều bình thường? Cho mình biết tại sao bạn lại kết luận như vậy.

# %% [markdown]
# YOUR ANSWER HERE
#
# Cột Id hầu như tất cả giá trị đều duy nhất → bình thường, đúng đặc tính của ID.
#
# Cột ParentIds cũng gần như duy nhất, chỉ có vài giá trị trùng lặp → bình thường.
#
# Cột AuthorName và AuthorEmail có số lượng giá trị hạn chế (55 và 58) → bình thường cho danh sách tác giả.
#
# Cột Subject có gần như mỗi commit một giá trị khác nhau (2058/2149) → bất thường nếu muốn phân nhóm, nhưng hợp lý vì mỗi commit thường có subject riêng.
#
# Kết luận:
#
# Về tổng thể, dữ liệu categorical không có lỗi lớn, nhưng cột Subject hầu như không thể dùng để nhóm vì mỗi giá trị gần như duy nhất.
#
# Nguyên nhân: đặc tính dữ liệu commit, mỗi subject là riêng biệt.

# %% [markdown]
# Kế tiếp, bạn hãy cho in ra các dòng mà có giá trị thiếu (in sao là tùy bạn, miễn là dễ nhìn). Sau đó, bạn hãy quan sát các dòng này để xem tại sao lại bị thiếu (trong trường hợp, bạn không biết tại sao thì cứ ghi nhận là không biết tại sao).

# %%
# YOUR CODE HERE
missing_rows_idx = [
    i for i in range(len(cols["Id"])) 
    if any(cols[col][i] == "" for col in cols)
]

for i in missing_rows_idx:
    row = {col: cols[col][i] for col in cols}
    print(f"Row {i+1}: {row}")
# Out:
# Row 1: {'Id': '606b6fd', 'ParentIds': 'c2d2cc2 55a4d01', 'AuthorName': 'M Bussonnier', 'AuthorEmail': 'bussonniermatthias@gmail.com', 'AuthorDate': datetime.datetime(2025, 10, 9, 11, 32, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #789 from Carreau/master-main', 'ChangedFiles': ''}
# Row 5: {'Id': 'ecf8996', 'ParentIds': '030509a 5e10953', 'AuthorName': 'M Bussonnier', 'AuthorEmail': 'bussonniermatthias@gmail.com', 'AuthorDate': datetime.datetime(2025, 10, 8, 13, 39, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #767 from jupyter/dependabot/github_actions/dot-github/workflows/actions/download-artifact-4.1.7', 'ChangedFiles': ''}
# Row 25: {'Id': '3dcdce3', 'ParentIds': '2f54b80 8806423', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 11, 10, 19, 18, 44, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #734 from jupyter/dependabot/npm_and_yarn/axios-1.6.1', 'ChangedFiles': ''}
# Row 27: {'Id': '2f54b80', 'ParentIds': '554c2d3 8ddfd5b', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 11, 10, 16, 31, 17, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #731 from vidartf/fix-mergepane-border', 'ChangedFiles': ''}
# Row 37: {'Id': 'e56e9fa', 'ParentIds': 'f718b7b 9695b00', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': '510760+vidartf@users.noreply.github.com', 'AuthorDate': datetime.datetime(2023, 11, 6, 18, 11, 25, tzinfo=datetime.timezone.utc), 'Subject': "Merge branch 'fix-mergepane-border' of https://github.com/vidartf/nbdime into fix-mergepane-border", 'ChangedFiles': ''}
# Row 46: {'Id': 'c1ea9b9', 'ParentIds': '997be80 9884381', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 11, 1, 12, 17, 50, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #639 from vidartf/cellid-diff', 'ChangedFiles': ''}
# Row 93: {'Id': '3c064bd', 'ParentIds': '83a768f e3a2bf1', 'AuthorName': 'Frédéric Collonval', 'AuthorEmail': 'fcollonval@users.noreply.github.com', 'AuthorDate': datetime.datetime(2023, 10, 16, 16, 9, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #711 from fcollonval/fix/apply-review-comments', 'ChangedFiles': ''}
# Row 112: {'Id': 'e6d2e28', 'ParentIds': '2db03bc 193ffcd', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 9, 27, 11, 5, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #692 from fcollonval/maintenance/add-src', 'ChangedFiles': ''}
# Row 113: {'Id': '2db03bc', 'ParentIds': 'f835a8b 0a7954e', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 9, 27, 10, 53, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #688 from krassowski/fix-pickers', 'ChangedFiles': ''}
# Row 117: {'Id': 'ac5eb35', 'ParentIds': 'ed70f8d d94b323', 'AuthorName': 'Frédéric Collonval', 'AuthorEmail': 'fcollonval@users.noreply.github.com', 'AuthorDate': datetime.datetime(2023, 9, 25, 10, 17, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #684 from fcollonval/maintenance/remove-noisy-log', 'ChangedFiles': ''}
# Row 122: {'Id': 'da240a2', 'ParentIds': '43168fc 872a71c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 9, 18, 10, 42, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #673 from HaudinFlorence/nbdime_upgraded', 'ChangedFiles': ''}
# Row 144: {'Id': '43168fc', 'ParentIds': '1b368a8 b6a5185', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 9, 8, 11, 52, 4, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #668 from HaudinFlorence/update_files_with_prettier_formatting', 'ChangedFiles': ''}
# Row 153: {'Id': 'b1804b1', 'ParentIds': 'e7a828d 53e1a9f', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 4, 30, 16, 20, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #666 from vidartf/fix-exit-code', 'ChangedFiles': ''}
# Row 164: {'Id': '691b9c8', 'ParentIds': '9fbfd46 df0353a', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 4, 22, 11, 28, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #656 from vidartf/nb6', 'ChangedFiles': ''}
# Row 169: {'Id': '9fbfd46', 'ParentIds': '50c9347 d5a3a48', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 3, 24, 23, 20, 15, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #657 from saiwing-yeung/master', 'ChangedFiles': ''}
# Row 170: {'Id': '50c9347', 'ParentIds': '2da614b 742e38f', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 3, 24, 22, 50, 11, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #651 from yan12125/unittest-mock', 'ChangedFiles': ''}
# Row 174: {'Id': '2da614b', 'ParentIds': '0d57918 498ae07', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 1, 15, 17, 22, 37, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #649 from vidartf/jps2', 'ChangedFiles': ''}
# Row 175: {'Id': '0d57918', 'ParentIds': 'a02615e 39bbff7', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 1, 15, 17, 9, 23, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #648 from mlucool/patch-1', 'ChangedFiles': ''}
# Row 180: {'Id': 'fe11ad5', 'ParentIds': 'f503763 3079951', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2023, 1, 14, 16, 10, 48, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #644 from singingwolfboy/py311', 'ChangedFiles': ''}
# Row 183: {'Id': 'f503763', 'ParentIds': '4bc7ae2 f67a809', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2022, 11, 24, 14, 42, 18, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #640 from singingwolfboy/patch-1', 'ChangedFiles': ''}
# Row 185: {'Id': '4bc7ae2', 'ParentIds': 'ecded88 9c190e0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2022, 7, 5, 17, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #623 from Daniel-Mietchen/patch-1', 'ChangedFiles': ''}
# Row 187: {'Id': 'ecded88', 'ParentIds': '2db0b44 4036fae', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2022, 6, 19, 10, 48, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #596 from icankeep/fix-checkpoint-async', 'ChangedFiles': ''}
# Row 188: {'Id': '2db0b44', 'ParentIds': 'fa4e2a3 480a421', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2022, 6, 19, 10, 46, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #615 from tallamjr/issues/240/prettyprint-black-terminal', 'ChangedFiles': ''}
# Row 189: {'Id': 'fa4e2a3', 'ParentIds': 'bbf621e dd4be20', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2022, 4, 18, 10, 42, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #617 from andriyor/patch-1', 'ChangedFiles': ''}
# Row 190: {'Id': 'bbf621e', 'ParentIds': 'fc31fbb 49c853e', 'AuthorName': 'Steven Silvester', 'AuthorEmail': 'steven.silvester@ieee.org', 'AuthorDate': datetime.datetime(2022, 4, 9, 5, 33, 57, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #618 from jupyter/blink1073-patch-1', 'ChangedFiles': ''}
# Row 193: {'Id': 'fc31fbb', 'ParentIds': '17d103c c01cbb8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2022, 2, 28, 10, 52, 19, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #589 from brunetton/patch-2', 'ChangedFiles': ''}
# Row 195: {'Id': '17d103c', 'ParentIds': '1b3f2b4 492bc23', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 11, 3, 11, 51, 16, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #605 from joelostblom/patch-1', 'ChangedFiles': ''}
# Row 198: {'Id': 'e44a5cc', 'ParentIds': 'f16d448 19fded3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 10, 25, 23, 51, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request from GHSA-p6rw-44q7-3fw4', 'ChangedFiles': ''}
# Row 199: {'Id': 'f16d448', 'ParentIds': '5f05329 eabc073', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 10, 25, 19, 10, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #607 from kr0p07k1n/python_310', 'ChangedFiles': ''}
# Row 206: {'Id': '5f05329', 'ParentIds': '559d785 36ecef6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 9, 30, 12, 8, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #604 from vidartf/fix-build', 'ChangedFiles': ''}
# Row 209: {'Id': '559d785', 'ParentIds': 'a74b538 b283d49', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 9, 30, 11, 19, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #603 from vidartf/fix-build', 'ChangedFiles': ''}
# Row 219: {'Id': '9df6aea', 'ParentIds': '524aac2 8201cd5', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 5, 25, 15, 15, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #593 from vidartf/fix-added-long-output', 'ChangedFiles': ''}
# Row 222: {'Id': '524aac2', 'ParentIds': '2994fb4 e4e696c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 20, 12, 27, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #586 from fcollonval/fcollonval/issue583', 'ChangedFiles': ''}
# Row 226: {'Id': 'ab8e60d', 'ParentIds': 'f1e18ff 23e0cc9', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 14, 18, 1, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #581 from vidartf/clenaup', 'ChangedFiles': ''}
# Row 228: {'Id': 'f1e18ff', 'ParentIds': '52f7990 6c1ce97', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 14, 17, 27, 12, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #572 from fcollonval/ft/federated-package', 'ChangedFiles': ''}
# Row 230: {'Id': '52f7990', 'ParentIds': '8ce708c 25252f6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 13, 19, 3, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #580 from fcollonval/fix/follow-up-576', 'ChangedFiles': ''}
# Row 240: {'Id': '8ce708c', 'ParentIds': '4291b8c dea43d6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 12, 1, 40, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #566 from krassowski/fix-cell-id-tests', 'ChangedFiles': ''}
# Row 245: {'Id': '075f502', 'ParentIds': '2d1edb8 4291b8c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 11, 21, 5, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': "Merge branch 'master' into pr/566", 'ChangedFiles': ''}
# Row 246: {'Id': '4291b8c', 'ParentIds': 'ab9f1bc 86c28f7', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 11, 21, 2, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #579 from vidartf/mathjax-server-ext', 'ChangedFiles': ''}
# Row 248: {'Id': 'ab9f1bc', 'ParentIds': 'c823623 295e834', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 4, 11, 14, 5, 53, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #576 from fcollonval/ft/jest', 'ChangedFiles': ''}
# Row 252: {'Id': 'fe2911a', 'ParentIds': 'c38cfc5 25101fe', 'AuthorName': 'Michał Krassowski', 'AuthorEmail': '5832902+krassowski@users.noreply.github.com', 'AuthorDate': datetime.datetime(2021, 3, 7, 11, 10, 34, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #1 from vidartf/id-tests', 'ChangedFiles': ''}
# Row 257: {'Id': 'a0726e5', 'ParentIds': '75363a0 8c52de8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 1, 14, 19, 2, 43, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #551 from ajbozarth/lab3', 'ChangedFiles': ''}
# Row 262: {'Id': '75363a0', 'ParentIds': 'f6beb60 206fee8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2021, 1, 7, 15, 4, 7, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #557 from jupyter/docs-details', 'ChangedFiles': ''}
# Row 278: {'Id': 'f6beb60', 'ParentIds': '92fc22d 4b1129b', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 10, 2, 20, 41, 4, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #546 from vidartf/merge-fixes', 'ChangedFiles': ''}
# Row 285: {'Id': '77cac58', 'ParentIds': 'b707946 ca3b311', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 9, 29, 14, 18, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #545 from vidartf/tool-beacon', 'ChangedFiles': ''}
# Row 287: {'Id': 'b707946', 'ParentIds': '141b2dc 598c072', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 9, 29, 12, 48, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #543 from vidartf/limit-stream-diff', 'ChangedFiles': ''}
# Row 290: {'Id': '141b2dc', 'ParentIds': '0f0a90a 4d2e319', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 9, 29, 12, 19, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #544 from vidartf/fix-merge-empty-base', 'ChangedFiles': ''}
# Row 296: {'Id': 'f259cae', 'ParentIds': '8804407 eaf9c06', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 9, 25, 16, 16, 16, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #538 from deanp70/master', 'ChangedFiles': ''}
# Row 297: {'Id': 'eaf9c06', 'ParentIds': 'bf5a540 a20c789', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 9, 25, 16, 57, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': "Merge branch 'wip' into pr/538", 'ChangedFiles': ''}
# Row 306: {'Id': 'd330173', 'ParentIds': '133c4bf 2cd6efe', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 9, 15, 12, 53, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #518 from vidartf/test-cleanup', 'ChangedFiles': ''}
# Row 307: {'Id': '133c4bf', 'ParentIds': 'a9435d5 326da89', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 9, 13, 59, 6, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #517 from vidartf/no-net', 'ChangedFiles': ''}
# Row 309: {'Id': 'a9435d5', 'ParentIds': 'a506b66 d4f8247', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 9, 13, 14, 12, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #516 from vidartf/th-config', 'ChangedFiles': ''}
# Row 313: {'Id': 'a506b66', 'ParentIds': 'd067442 fed6e17', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 6, 21, 54, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #514 from jupyter/vidartf-patch-1', 'ChangedFiles': ''}
# Row 314: {'Id': 'd067442', 'ParentIds': 'd9cbd7b 9b67c6c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 5, 19, 2, 8, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #515 from vidartf/cleanup', 'ChangedFiles': ''}
# Row 324: {'Id': 'd9cbd7b', 'ParentIds': '425c46d f036d20', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2020, 3, 5, 11, 16, 54, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #512 from blink1073/jlab-2.0-final', 'ChangedFiles': ''}
# Row 326: {'Id': '425c46d', 'ParentIds': '6259cd0 ce08ccf', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2020, 1, 23, 10, 10, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #508 from blink1073/jlab-2.0', 'ChangedFiles': ''}
# Row 331: {'Id': '6259cd0', 'ParentIds': '137182a 0dbe870', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 11, 20, 13, 34, 11, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #502 from kynan/long-description', 'ChangedFiles': ''}
# Row 332: {'Id': '137182a', 'ParentIds': 'a9faba1 cd528a8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 11, 19, 10, 30, 48, tzinfo=datetime.timezone.utc), 'Subject': 'Merge pull request #504 from minrk/drop-py2', 'ChangedFiles': ''}
# Row 339: {'Id': 'a9faba1', 'ParentIds': 'cdadb44 e114af0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 8, 31, 23, 59, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #498 from dniku/master', 'ChangedFiles': ''}
# Row 341: {'Id': 'cdadb44', 'ParentIds': 'ec065a7 0810fa3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 8, 7, 11, 33, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #491 from dotmesh-io/addrange-removerange-conflict-take-2', 'ChangedFiles': ''}
# Row 356: {'Id': '300067c', 'ParentIds': '0590d1b b9d972e', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 7, 25, 16, 19, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #483 from vidartf/labupdate', 'ChangedFiles': ''}
# Row 368: {'Id': '0590d1b', 'ParentIds': '1f864d2 c3c652e', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 6, 14, 13, 46, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #477 from vidartf/web-config', 'ChangedFiles': ''}
# Row 373: {'Id': 'fabbeb7', 'ParentIds': 'ba18b56 b75bfa7', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 5, 16, 14, 36, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #475 from vidartf/fix-styling', 'ChangedFiles': ''}
# Row 376: {'Id': 'ba18b56', 'ParentIds': 'c2635db 0509d39', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 4, 29, 13, 18, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #466 from lebedov/nbshow-colorize', 'ChangedFiles': ''}
# Row 389: {'Id': '8940d58', 'ParentIds': '0910bcd 4f5cdde', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 3, 5, 16, 18, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #465 from Godley/master', 'ChangedFiles': ''}
# Row 392: {'Id': '0910bcd', 'ParentIds': 'b8c7829 95fe0aa', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 3, 4, 11, 4, 48, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #462 from vidartf/fix-cm-max-height', 'ChangedFiles': ''}
# Row 393: {'Id': 'b8c7829', 'ParentIds': '91ac9bf 384acd9', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 3, 4, 10, 41, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #463 from Godley/master', 'ChangedFiles': ''}
# Row 396: {'Id': '91ac9bf', 'ParentIds': '31b716e 8e65719', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 3, 1, 15, 28, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #460 from jupyter/fa-https', 'ChangedFiles': ''}
# Row 398: {'Id': '31b716e', 'ParentIds': '07714c0 5ab35e7', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 3, 1, 9, 9, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #457 from minrk/remote-access', 'ChangedFiles': ''}
# Row 400: {'Id': '07714c0', 'ParentIds': '435ce3b f79fd54', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2019, 2, 28, 13, 0, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #450 from vidartf/fix-unhide-update', 'ChangedFiles': ''}
# Row 401: {'Id': '435ce3b', 'ParentIds': 'd71758d 027145e', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2019, 2, 18, 10, 59, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #454 from minrk/path-arg-type', 'ChangedFiles': ''}
# Row 406: {'Id': 'c24fc22', 'ParentIds': '5a92521 93095de', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 12, 18, 14, 43, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #441 from vidartf/oldgit', 'ChangedFiles': ''}
# Row 408: {'Id': '5a92521', 'ParentIds': 'ed222a2 eac7bc6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 11, 19, 11, 39, 50, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #438 from vidartf/empty-merge-base', 'ChangedFiles': ''}
# Row 411: {'Id': 'ed222a2', 'ParentIds': 'd44e3b5 b669e85', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 11, 19, 10, 52, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #439 from vidartf/chore-tests', 'ChangedFiles': ''}
# Row 416: {'Id': 'abdde8f', 'ParentIds': '20e07f4 58c5197', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 10, 18, 12, 49, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #433 from vidartf/fix-nbmerge-doc', 'ChangedFiles': ''}
# Row 423: {'Id': 'd3a0962', 'ParentIds': '60a93bc fefdbe5', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 10, 8, 14, 9, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #430 from vidartf/update-lab', 'ChangedFiles': ''}
# Row 428: {'Id': '959ce75', 'ParentIds': '98c3af9 091bdea', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 10, 5, 13, 35, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #421 from vidartf/fix-mathjax', 'ChangedFiles': ''}
# Row 431: {'Id': '98c3af9', 'ParentIds': '98bf4dc 9d36c6b', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 9, 27, 16, 54, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #429 from vidartf/lint2', 'ChangedFiles': ''}
# Row 434: {'Id': '98bf4dc', 'ParentIds': 'c968e6f ac9647b', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 9, 27, 13, 31, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #428 from vidartf/config-pp', 'ChangedFiles': ''}
# Row 437: {'Id': 'c968e6f', 'ParentIds': 'd070da0 0970ed3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 9, 14, 11, 38, 7, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #424 from vidartf/unchanged', 'ChangedFiles': ''}
# Row 446: {'Id': 'eef0e50', 'ParentIds': '14137b6 c591417', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 9, 3, 17, 32, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #422 from vidartf/fix-mergetool-save', 'ChangedFiles': ''}
# Row 451: {'Id': '559bae6', 'ParentIds': '039c821 7111b70', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 8, 29, 15, 52, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #420 from vidartf/lab-update', 'ChangedFiles': ''}
# Row 454: {'Id': 'fb6484a', 'ParentIds': '3d7d95e 54cf807', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 8, 16, 15, 15, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #416 from vidartf/fix-filter', 'ChangedFiles': ''}
# Row 461: {'Id': '3fc3e9a', 'ParentIds': 'a93b42c abc3939', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 7, 31, 16, 27, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #407 from vidartf/deps', 'ChangedFiles': ''}
# Row 463: {'Id': 'a93b42c', 'ParentIds': '9cf252c 4605e25', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 7, 31, 15, 3, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #409 from vidartf/workaround-localhosts', 'ChangedFiles': ''}
# Row 466: {'Id': '9cf252c', 'ParentIds': 'fc1af0c ff9642c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 25, 16, 21, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #403 from vidartf/fix-config', 'ChangedFiles': ''}
# Row 467: {'Id': 'fc1af0c', 'ParentIds': '69585e7 229bd68', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 25, 15, 58, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #400 from vidartf/optimize-diff2', 'ChangedFiles': ''}
# Row 476: {'Id': '220bc1f', 'ParentIds': 'cf45e47 7df4bc8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 19, 15, 49, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #399 from vidartf/fix-dependency', 'ChangedFiles': ''}
# Row 477: {'Id': 'cf45e47', 'ParentIds': '7748bd5 020a00d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 19, 15, 44, 7, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #398 from vidartf/tweak-config', 'ChangedFiles': ''}
# Row 480: {'Id': '7748bd5', 'ParentIds': 'a83fdb1 e39f5e7', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 19, 10, 37, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #397 from vidartf/doc-dev-install', 'ChangedFiles': ''}
# Row 483: {'Id': 'f0d66a6', 'ParentIds': '0e47f41 035b3d6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 18, 10, 58, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #395 from vidartf/focus-edit', 'ChangedFiles': ''}
# Row 484: {'Id': '0e47f41', 'ParentIds': '32df48a e675aa0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 15, 12, 33, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #394 from vidartf/ext-ignore-flags', 'ChangedFiles': ''}
# Row 487: {'Id': '32df48a', 'ParentIds': 'f50d8e5 c8cfaa0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 14, 13, 18, 12, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #393 from vidartf/devinstall', 'ChangedFiles': ''}
# Row 490: {'Id': 'f50d8e5', 'ParentIds': 'bf8da35 fa0590c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 13, 15, 4, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #390 from vidartf/config-cleanup', 'ChangedFiles': ''}
# Row 498: {'Id': 'bf8da35', 'ParentIds': '83976ac 4c2f423', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 13, 13, 32, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #389 from vidartf/nbconfig-fix', 'ChangedFiles': ''}
# Row 505: {'Id': 'c30847b', 'ParentIds': 'ef9d708 e18d8b6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 11, 13, 44, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #384 from vidartf/config-fix', 'ChangedFiles': ''}
# Row 506: {'Id': 'ef9d708', 'ParentIds': '1bb9458 e67a71d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 11, 13, 43, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #385 from vidartf/fix-style', 'ChangedFiles': ''}
# Row 510: {'Id': '1bb9458', 'ParentIds': '25878a5 151415d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 11, 9, 55, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #382 from toddrme2178/patch-1', 'ChangedFiles': ''}
# Row 512: {'Id': '25878a5', 'ParentIds': '0234912 35309cd', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 8, 15, 51, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #381 from vidartf/fix-python-spec', 'ChangedFiles': ''}
# Row 513: {'Id': '0234912', 'ParentIds': 'e510209 8c614c0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 6, 8, 15, 51, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #380 from vidartf/inline-source', 'ChangedFiles': ''}
# Row 517: {'Id': 'e510209', 'ParentIds': '0e1c4d6 5371adc', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 24, 15, 20, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #378 from vidartf/fix-dot-diff', 'ChangedFiles': ''}
# Row 528: {'Id': '1b332c8', 'ParentIds': 'ffaaf75 e96b96d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 15, 10, 11, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #377 from vidartf/lab-fixes', 'ChangedFiles': ''}
# Row 529: {'Id': 'ffaaf75', 'ParentIds': '28a436b 031c2dc', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 14, 19, 38, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #376 from vidartf/collapser', 'ChangedFiles': ''}
# Row 530: {'Id': '28a436b', 'ParentIds': 'b7ececa 8ad275e', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 14, 18, 20, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #375 from vidartf/cleanup', 'ChangedFiles': ''}
# Row 543: {'Id': '52e68c8', 'ParentIds': '09ce7af 4b55685', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 8, 11, 22, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #374 from vidartf/manual-edit-extract', 'ChangedFiles': ''}
# Row 555: {'Id': '09ce7af', 'ParentIds': 'bd9873c 0d197ea', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 7, 14, 34, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #371 from vidartf/chunks', 'ChangedFiles': ''}
# Row 561: {'Id': 'bd9873c', 'ParentIds': 'f330467 fdaf9c3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 7, 9, 46, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #372 from minrk/utf-8', 'ChangedFiles': ''}
# Row 563: {'Id': 'f330467', 'ParentIds': '789e5b4 ba00a8d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 4, 16, 12, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #370 from vidartf/cleanup', 'ChangedFiles': ''}
# Row 569: {'Id': '2656120', 'ParentIds': '145efe3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 3, 14, 51, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'nbdime-jupyterlab@0.1.0', 'ChangedFiles': ''}
# Row 571: {'Id': '55d56ee', 'ParentIds': 'd59a446 b58a9d8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 2, 20, 1, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #369 from vidartf/cleanup', 'ChangedFiles': ''}
# Row 577: {'Id': 'd59a446', 'ParentIds': '14c7c0a 1e9d547', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 5, 2, 17, 38, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #298 from vidartf/jlab-ext', 'ChangedFiles': ''}
# Row 585: {'Id': 'e03c861', 'ParentIds': '7914988 ae8f008', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 4, 28, 14, 1, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #366 from jtpio/patch-1', 'ChangedFiles': ''}
# Row 587: {'Id': '7914988', 'ParentIds': '0a60cdc 1d7b23d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 4, 27, 13, 2, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #365 from vidartf/cleanup', 'ChangedFiles': ''}
# Row 591: {'Id': '0a60cdc', 'ParentIds': '35c3c96 cbcc974', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 4, 25, 15, 17, 21, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #363 from vidartf/update_deps', 'ChangedFiles': ''}
# Row 602: {'Id': 'e4b9dc6', 'ParentIds': '66cc086 04af6c9', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 4, 3, 16, 16, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #357 from vidartf/trust-outputs', 'ChangedFiles': ''}
# Row 620: {'Id': '670e8a0', 'ParentIds': '12dd2ab fb5560a', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 22, 17, 16, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #355 from vidartf/config-ignore', 'ChangedFiles': ''}
# Row 626: {'Id': '77398e0', 'ParentIds': 'f16ecac 6277ec7', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 22, 17, 13, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #354 from vidartf/config', 'ChangedFiles': ''}
# Row 627: {'Id': 'f16ecac', 'ParentIds': '350f5ca 961c568', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 22, 16, 43, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #356 from vidartf/fix-differ', 'ChangedFiles': ''}
# Row 636: {'Id': '350f5ca', 'ParentIds': '8d6421d 0a8342c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 21, 17, 26, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #353 from vidartf/test-flags', 'ChangedFiles': ''}
# Row 637: {'Id': '8d6421d', 'ParentIds': 'ac7358f 5c25fd0', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 21, 16, 56, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #352 from vidartf/ignore-generic', 'ChangedFiles': ''}
# Row 642: {'Id': 'ac7358f', 'ParentIds': '7c4b998 c155592', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 16, 50, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #335 from vidartf/git-filter', 'ChangedFiles': ''}
# Row 643: {'Id': '7c4b998', 'ParentIds': 'c21fd7f 3dd98b6', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 16, 50, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #350 from vidartf/concurrent-web', 'ChangedFiles': ''}
# Row 644: {'Id': 'c21fd7f', 'ParentIds': 'eac0417 c432a92', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 16, 11, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #349 from vidartf/web-updated', 'ChangedFiles': ''}
# Row 657: {'Id': 'eac0417', 'ParentIds': 'e019d4c 18525fa', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 15, 14, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #347 from vidartf/concurrent-inserts', 'ChangedFiles': ''}
# Row 658: {'Id': 'e019d4c', 'ParentIds': '05c5047 719f66a', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 14, 49, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #346 from vidartf/persist-flag', 'ChangedFiles': ''}
# Row 659: {'Id': '05c5047', 'ParentIds': 'f0a36a1 fdf07ba', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 3, 14, 14, 20, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #348 from vidartf/tornado', 'ChangedFiles': ''}
# Row 666: {'Id': 'f0a36a1', 'ParentIds': '344a450 6f54c3d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 2, 27, 11, 19, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #344 from vidartf/jinja-ver', 'ChangedFiles': ''}
# Row 668: {'Id': '344a450', 'ParentIds': '4022e8c 8a69ef3', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2018, 1, 8, 15, 59, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #340 from vidartf/extension-error-handling', 'ChangedFiles': ''}
# Row 670: {'Id': '4022e8c', 'ParentIds': 'f0284ac 461fd66', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2018, 1, 3, 13, 53, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #339 from vidartf/fix-ext-templates', 'ChangedFiles': ''}
# Row 672: {'Id': 'f0284ac', 'ParentIds': 'ff6e1fd 588b9ab', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 12, 12, 11, 10, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #336 from JarnoRFB/master', 'ChangedFiles': ''}
# Row 682: {'Id': '2354345', 'ParentIds': 'f884858 8345baf', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 29, 17, 11, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #332 from vidartf/log-adjust', 'ChangedFiles': ''}
# Row 683: {'Id': 'f884858', 'ParentIds': 'dfff8ff 92b5b0c', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 28, 16, 57, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #333 from vidartf/difftool-reload', 'ChangedFiles': ''}
# Row 689: {'Id': 'dfff8ff', 'ParentIds': '7240999 e4a223d', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 28, 16, 16, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #331 from vidartf/server-poll', 'ChangedFiles': ''}
# Row 690: {'Id': '7240999', 'ParentIds': 'd5a3b66 f883682', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 28, 16, 16, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #329 from vidartf/mathjax', 'ChangedFiles': ''}
# Row 693: {'Id': 'd5a3b66', 'ParentIds': 'e81d466 0f13db4', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 28, 15, 5, 8, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #330 from vidartf/drop-py3.3', 'ChangedFiles': ''}
# Row 697: {'Id': 'e81d466', 'ParentIds': 'f7cedce 519db53', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 27, 13, 0, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #326 from vidartf/fix-layout', 'ChangedFiles': ''}
# Row 702: {'Id': 'ce16aec', 'ParentIds': 'c1a95e1 3bc3009', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 10, 15, 49, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #322 from vidartf/changelog0.4', 'ChangedFiles': ''}
# Row 704: {'Id': 'c1a95e1', 'ParentIds': 'cd5403a 380d246', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 10, 15, 31, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #321 from minrk/packaging', 'ChangedFiles': ''}
# Row 708: {'Id': '06784cd', 'ParentIds': '13d10af 333a696', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 8, 14, 27, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #320 from vidartf/webdiff-rel-img', 'ChangedFiles': ''}
# Row 710: {'Id': '13d10af', 'ParentIds': '31233af 8d21f14', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 8, 11, 18, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #319 from vidartf/mifor-fixes', 'ChangedFiles': ''}
# Row 714: {'Id': '31233af', 'ParentIds': 'a70fc47 4ac94e0', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 7, 20, 56, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #318 from vidartf/color-words', 'ChangedFiles': ''}
# Row 715: {'Id': 'a70fc47', 'ParentIds': '3b51405 a51d525', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 7, 20, 55, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #317 from vidartf/sxs', 'ChangedFiles': ''}
# Row 722: {'Id': '85b9439', 'ParentIds': 'fd10644 512be11', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 6, 17, 19, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #316 from minrk/pp-diff-typo', 'ChangedFiles': ''}
# Row 725: {'Id': 'fd10644', 'ParentIds': '7bb9fae 864add9', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 6, 10, 57, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #297 from vidartf/nbdime-notebook-ext', 'ChangedFiles': ''}
# Row 726: {'Id': '7bb9fae', 'ParentIds': 'a184e7e 56490f8', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2017, 11, 4, 23, 16, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #315 from einon/patch-1', 'ChangedFiles': ''}
# ...
# Row 1634: {'Id': '89974ba', 'ParentIds': '618b233 d956efd', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2016, 10, 5, 10, 33, 59, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #83 from jupyter/martinal/topic-cli-fixes', 'ChangedFiles': ''}
# Row 1641: {'Id': '2bed9bb', 'ParentIds': '9824304 e40a88b', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 10, 4, 8, 59, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #82 from vidartf/docs', 'ChangedFiles': ''}
# Row 1654: {'Id': '9824304', 'ParentIds': '88acecf dc14211', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 9, 27, 9, 59, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #81 from vidartf/refactorprojects', 'ChangedFiles': ''}
# Row 1659: {'Id': '88acecf', 'ParentIds': 'fe87b7a 4fe2a23', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 9, 23, 10, 42, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #77 from vidartf/webapp_mergetool', 'ChangedFiles': ''}
# Row 1660: {'Id': 'fe87b7a', 'ParentIds': 'ce4583a cb5275c', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 9, 23, 9, 54, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #79 from vidartf/mergetool_driver_server', 'ChangedFiles': ''}
# Row 1661: {'Id': 'ce4583a', 'ParentIds': 'b94db84 fe72eb4', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 9, 23, 9, 53, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #78 from vidartf/server_fixes', 'ChangedFiles': ''}
# Row 1763: {'Id': 'b94db84', 'ParentIds': 'd24fe80 4b4c358', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 9, 12, 15, 5, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #76 from vidartf/merge-decisions', 'ChangedFiles': ''}
# Row 1790: {'Id': 'd24fe80', 'ParentIds': '4e75c5a bd14f06', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 8, 29, 13, 10, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #75 from vidartf/merge_decision_schema', 'ChangedFiles': ''}
# Row 1834: {'Id': '4e75c5a', 'ParentIds': '90ede10 41a95d2', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 27, 16, 7, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #68 from vidartf/fix_metadata', 'ChangedFiles': ''}
# Row 1835: {'Id': '90ede10', 'ParentIds': 'b6b9876 bcd6141', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 27, 16, 6, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #73 from jupyter/martinal/fix-autoresolve-bug', 'ChangedFiles': ''}
# Row 1840: {'Id': 'b6b9876', 'ParentIds': '767c7c2 32bafb5', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 7, 27, 8, 37, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #71 from vidartf/refactor_chunking', 'ChangedFiles': ''}
# Row 1849: {'Id': '767c7c2', 'ParentIds': '84bb398 c4a5cc0', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 7, 26, 15, 47, 4, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #72 from vidartf/patch-1', 'ChangedFiles': ''}
# Row 1853: {'Id': '84bb398', 'ParentIds': '37a15fe 9033e8a', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 26, 10, 3, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #67 from vidartf/render_md', 'ChangedFiles': ''}
# Row 1856: {'Id': '37a15fe', 'ParentIds': 'ed9023a 2935e8b', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 25, 14, 40, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #65 from gahjelle/setup_with_webapp', 'ChangedFiles': ''}
# Row 1866: {'Id': 'b3343f9', 'ParentIds': '8ff220d 845c477', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 15, 4, 0, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #63 from minrk/diff-driver-attributes', 'ChangedFiles': ''}
# Row 1871: {'Id': 'e387105', 'ParentIds': '55adbce a8650be', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 15, 0, 41, 17, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #62 from minrk/merge-test', 'ChangedFiles': ''}
# Row 1876: {'Id': '55adbce', 'ParentIds': '633fe82 15c6740', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 23, 12, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #61 from minrk/install-web', 'ChangedFiles': ''}
# Row 1884: {'Id': '633fe82', 'ParentIds': 'd1952dc 754f57b', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 18, 46, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #58 from minrk/turn-on-indent', 'ChangedFiles': ''}
# Row 1886: {'Id': 'd1952dc', 'ParentIds': '6691bfc 7e4d860', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 14, 42, 34, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #54 from minrk/colors', 'ChangedFiles': ''}
# Row 1887: {'Id': '6691bfc', 'ParentIds': '0d57ff7 9c6830a', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 14, 14, 10, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #57 from minrk/skip-non-notebooks', 'ChangedFiles': ''}
# Row 1891: {'Id': 'a8fce37', 'ParentIds': '3fd06d8 d390fef', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 10, 44, 20, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #56 from minrk/missing-languages', 'ChangedFiles': ''}
# Row 1894: {'Id': '0d9469d', 'ParentIds': '312418e 8662fe3', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 10, 37, 52, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #55 from minrk/integer-ports', 'ChangedFiles': ''}
# Row 1895: {'Id': '312418e', 'ParentIds': '5044f27 18814a6', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 14, 1, 5, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #50 from vidartf/mimetype_diff', 'ChangedFiles': ''}
# Row 1898: {'Id': '5044f27', 'ParentIds': '7fcd5b2 fecb37f', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 13, 16, 32, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), 'Subject': 'Merge pull request #49 from vidartf/webapp_difftool', 'ChangedFiles': ''}
# Row 1901: {'Id': '015483b', 'ParentIds': 'dcd6c22 038689b', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 7, 22, 48, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': "Merge remote-tracking branch 'origin/linewise_diffs' into mimetype_diff", 'ChangedFiles': ''}
# Row 1923: {'Id': 'b91fc89', 'ParentIds': '9473ab1 7fcd5b2', 'AuthorName': 'Vidar Tonaas Fauske', 'AuthorEmail': 'vidartf@gmail.com', 'AuthorDate': datetime.datetime(2016, 7, 7, 14, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': "Merge remote-tracking branch 'jupyter/master' into webapp_difftool", 'ChangedFiles': ''}
# Row 1934: {'Id': '7fcd5b2', 'ParentIds': 'a3504cb d3694eb', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 5, 11, 14, 24, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #48 from bollwyvl/handle-error-output-type', 'ChangedFiles': ''}
# Row 1941: {'Id': 'a3504cb', 'ParentIds': 'b363220 fde642d', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 5, 4, 17, 4, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #45 from vidartf/FIX_diff_driver_test', 'ChangedFiles': ''}
# Row 1943: {'Id': 'b363220', 'ParentIds': '614882b f6f80ac', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 5, 4, 11, 51, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #44 from vidartf/diff_driver', 'ChangedFiles': ''}
# Row 1944: {'Id': '614882b', 'ParentIds': '2e6aba7 1b0320c', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 5, 4, 11, 47, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #43 from vidartf/ignores', 'ChangedFiles': ''}
# Row 1945: {'Id': '2e6aba7', 'ParentIds': '9a2d724 d54c67f', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 5, 4, 11, 47, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #42 from vidartf/misname', 'ChangedFiles': ''}
# Row 1953: {'Id': 'cc31347', 'ParentIds': 'a0303a4 ebd3f33', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 4, 21, 14, 34, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #41 from bollwyvl/topic-prettydiff-fallback', 'ChangedFiles': ''}
# Row 1956: {'Id': 'a0303a4', 'ParentIds': '912ee20 3fefdc8', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 4, 18, 10, 25, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #40 from willingc/doc-move', 'ChangedFiles': ''}
# Row 1962: {'Id': '912ee20', 'ParentIds': 'f173d83 d5312de', 'AuthorName': 'Carol Willing', 'AuthorEmail': 'carolcode@willingconsulting.com', 'AuthorDate': datetime.datetime(2016, 4, 17, 3, 38, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'Subject': 'Merge pull request #39 from jupyter/willingc-patch-1', 'ChangedFiles': ''}
# Row 1964: {'Id': 'f173d83', 'ParentIds': 'd15e6fd 8e67844', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 4, 15, 16, 3, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'Subject': 'Merge pull request #38 from jupyter/new-list-merge-algorithm', 'ChangedFiles': ''}
# Row 1988: {'Id': 'd15e6fd', 'ParentIds': 'cc37433 149ddce', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 3, 22, 12, 0, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #31 from minrk/terminal-diff', 'ChangedFiles': ''}
# Row 1996: {'Id': 'bc2bbfc', 'ParentIds': '715eb15 f14e094', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 3, 21, 10, 11, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #30 from willingc/doc-update', 'ChangedFiles': ''}
# Row 2008: {'Id': '6660a4a', 'ParentIds': '72fc51f d60af42', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 15, 14, 23, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #29 from martinal/martinal/topic-merge-conflict-resolution', 'ChangedFiles': ''}
# Row 2013: {'Id': '72fc51f', 'ParentIds': 'fbcb81f dc2407b', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 3, 12, 21, 53, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #28 from minrk/fix-difftool-args', 'ChangedFiles': ''}
# Row 2015: {'Id': 'fbcb81f', 'ParentIds': '5af7f14 0a8e244', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 8, 14, 30, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #27 from martinal/martinal/topic-refactor-diffing', 'ChangedFiles': ''}
# Row 2017: {'Id': '5af7f14', 'ParentIds': '24a29c2 f95b939', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 8, 13, 56, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #26 from minrk/difftool', 'ChangedFiles': ''}
# Row 2023: {'Id': '24a29c2', 'ParentIds': 'c261edd 88f0961', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 8, 10, 46, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #25 from martinal/martinal/topic-add-merge-strategies', 'ChangedFiles': ''}
# Row 2024: {'Id': 'c261edd', 'ParentIds': 'd20e604 7164a48', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 8, 10, 42, 18, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #24 from martinal/martinal/topic-refactor-diff-algorithms', 'ChangedFiles': ''}
# Row 2028: {'Id': 'd20e604', 'ParentIds': '91318f6 1333a20', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 3, 7, 14, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #22 from martinal/martinal/topic-use-argparse', 'ChangedFiles': ''}
# Row 2030: {'Id': '91318f6', 'ParentIds': 'dc6604c 32ec755', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2016, 2, 23, 15, 5, 27, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #21 from martinal/api-draft', 'ChangedFiles': ''}
# Row 2032: {'Id': 'dc6604c', 'ParentIds': '7ae62b8 0d9e8ce', 'AuthorName': 'Min RK', 'AuthorEmail': 'benjaminrk@gmail.com', 'AuthorDate': datetime.datetime(2016, 2, 22, 11, 37, 8, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Merge pull request #20 from WillEngler/web-cli', 'ChangedFiles': ''}
# Row 2149: {'Id': 'f87fb2e', 'ParentIds': '', 'AuthorName': 'Martin Sandve Alnæs', 'AuthorEmail': 'martinal@simula.no', 'AuthorDate': datetime.datetime(2015, 11, 9, 13, 13, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'Subject': 'Initial commit, framework files following nbformat setup.', 'ChangedFiles': 'CONTRIBUTING.md,COPYING.md,MANIFEST.in,README.md,docs/README.md,nbmerge/__init__.py,nbmerge/_version.py,scripts/nbdiff,scripts/nbmerge,setup.cfg,setup.py'}

# %% [markdown]
# YOUR ANSWER HERE
#
# Tất cả các dòng có giá trị thiếu đều nằm ở cột ChangedFiles.
#
# Nguyên nhân hợp lý: những dòng này là các commit merge (thường là merge pull request), nên không có thay đổi trực tiếp trong file, dẫn đến ChangedFiles trống.
#
# Không có giá trị thiếu ở các cột quan trọng khác như Id, AuthorName, AuthorEmail, AuthorDate.
#
# ### Kết luận:
#
# Việc thiếu dữ liệu ở ChangedFiles là bình thường do đặc tính commit merge.
#
# Không phát hiện nguyên nhân bất thường khác.

# %% [markdown]
# ---

# %% [markdown]
# ## Đưa ra câu hỏi có ý nghĩa cần trả lời

# %% [markdown]
# Sau khi khám phá dữ liệu, ta đã hiểu hơn về dữ liệu. Bây giờ, ta hãy xem thử có câu hỏi nào có ý nghĩa mà có thể được trả lời bằng dữ liệu này không.
#
# Các câu hỏi có thể có là:
# - *Câu hỏi 1: trong năm 2021, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để khen thưởng
# - *Câu hỏi 2: commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để đổ tội cho tác giả của commit đó ;-)

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 1 (1đ)

# %% [markdown]
# Nhắc lại câu hỏi 1: *trong năm 2023, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?*
#
# Bạn sẽ lưu kết quả vào biến `wanted_people`. Biến này là một dictionary, mỗi phần tử ứng với một người mà có commit trong năm 2023, key là tên của người đó, value là số lượng commit của người đó. Dictionary này được sort theo value giảm dần.

# %%
# YOUR CODE HERE
commit_2023_idx = [i for i in range(len(cols["AuthorDate"]))
                   if cols["AuthorDate"][i].year == 2023]

author_counts = {}
for i in commit_2023_idx:
    author = cols["AuthorName"][i]
    if author in author_counts:
        author_counts[author] += 1
    else:
        author_counts[author] = 1
wanted_people = dict(sorted(author_counts.items(), key=lambda x: x[1], reverse=True))

# %%
# TEST
correct_wanted_people = {'Vidar Tonaas Fauske': 62,
                         'Frédéric Collonval': 31,
                         'Florence Haudin': 18,
                         'github-actions[bot]': 14,
                         'fcollonval': 4,
                         'dependabot[bot]': 4,
                         'HaudinFlorence': 4,
                         'krassowski': 3,
                         'Michał Krassowski': 3,
                         'Chih-Hsuan Yen': 2,
                         'Angus Hollands': 1,
                         'Min RK': 1,
                         'Johan Mabille': 1,
                         'Saiwing Yeung': 1,
                         'Cory Gwin': 1}
assert wanted_people == correct_wanted_people

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 2 (2đ)

# %% [markdown]
# Nhắc lại câu hỏi 2: *commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?*
#
# Ta thống nhất: không xét các commit "merge pull request" vì các commit này không có thông tin về "ChangedFiles".
#
# Bạn lưu kết quả vào biến `wanted_commit`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một thông tin của commit, key là tên cột, value là giá trị tương ứng.

# %%
# YOUR CODE HERE
target_file = "nbdime/webapp/templates/difftool.html"
latest_date = None
latest_commit_index = -1

num_commits = len(cols['Id'])
for i in range(num_commits):
    files_str = cols['ChangedFiles'][i]
    if files_str == "":
        continue
    
    individual_files = files_str.split(',')
    if target_file in individual_files:
        current_date = cols['AuthorDate'][i]
        if latest_date is None or current_date > latest_date:
            latest_date = current_date
            latest_commit_index = i

wanted_commit = {}
if latest_commit_index != -1:
    for col_name in cols:
        wanted_commit[col_name] = cols[col_name][latest_commit_index]

# %%
# TEST
correct_wanted_commit = {'Id': 'd39f45a',
 'ParentIds': '8ebbc6e',
 'AuthorName': 'Frédéric Collonval',
 'AuthorEmail': 'fcollonval@users.noreply.github.com',
 'AuthorDate': datetime.datetime(2023, 10, 20, 23, 20, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))),
 'Subject': 'Do not collapse editor lines in single editor (#719)',
 'ChangedFiles': 'nbdime/webapp/templates/compare.html,nbdime/webapp/templates/diff.html,nbdime/webapp/templates/difftool.html,nbdime/webapp/templates/merge.html,nbdime/webapp/templates/mergetool.html,packages/nbdime/src/common/mergeview.ts,ui-tests/data/merge_test6/center.ipynb,ui-tests/data/merge_test6/left.ipynb,ui-tests/data/merge_test6/right.ipynb,ui-tests/package-lock.json,ui-tests/tests/nbdime-merge-test6.spec.ts,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-linux.png,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-win32.png'}
assert wanted_commit == correct_wanted_commit
